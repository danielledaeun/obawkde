# %% [markdown]
# # Synthetic data results
# - from statsmodels.stats.anova import AnovaRM
# ## Table for each synthetic data
# - get the very last value of each column

# %%
import pandas as pd
from typing import List
result_path = "/Users/i551797/Documents/thesis-tensorflow/res"
boundary = 'sea' # 'sine', 'sea', 'circle'
imtype = 'noise' # 'safe', 'borderline', 'noise'
ir = '10' # '10', '1', '0'
# path
path = f"{result_path}/{boundary}/{imtype}/{ir}"
# methods and metrics
methods = ['baseline', 'sliding', 'oob_single', 'areba', 'mine'] #'oob', 
metrics = ['rec0', 'rec1', 'gmu']

# get the final value of a metric for a method
def final_value(path:str, method:str, metric:str) -> pd.Series:
    df = pd.read_csv(f"{path}/{method}_{metric}.csv")
    return df.iloc[:, -1]

def summary_table(path:str, methods:List[str], metrics:List[str]) -> pd.DataFrame:  
    results = []
    for method in methods:
        for metric in metrics:
            mean, std = final_value(path, method, metric).mean(), final_value(path, method, metric).std()
            results.append([method, metric, mean, std])
    return pd.DataFrame(results, columns=['method', 'metric', 'mean', 'std'])
print(path)
summary_table(path, methods, metrics)
# Out:
# /Users/i551797/Documents/thesis-tensorflow/res/sea/noise/10
#         method metric      mean       std
# 0     baseline   rec0  0.979029  0.009788
# 1     baseline   rec1  0.432631  0.032299
# 2     baseline    gmu  0.650312  0.023568
# 3      sliding   rec0  0.980310  0.008487
# 4      sliding   rec1  0.424567  0.033156
# 5      sliding    gmu  0.644622  0.024936
# 6   oob_single   rec0  0.948794  0.016977
# 7   oob_single   rec1  0.475015  0.029859
# 8   oob_single    gmu  0.670951  0.021296
# 9        areba   rec0  0.957506  0.041051
# 10       areba   rec1  0.417502  0.095333
# 11       areba    gmu  0.626535  0.067932
# 12        mine   rec0  0.783792  0.068255
# 13        mine   rec1  0.596463  0.035105
# 14        mine    gmu  0.682546  0.032164

# %% [markdown]
# ## Full results table

# %%
def table_res_column(path: str, metric: str) -> pd.DataFrame:
    """Create a results table for a specific metric and path"""
    # Define methods
    methods = ['mine', 'baseline', 'sliding', 'oob_single', 'areba'] # 'oob'
    
    # Get final values for each method
    results = []
    for method in methods:
        mean, std = final_value(path, method, metric).mean(), final_value(path, method, metric).std()
        results.append([mean, std])
    
    # Create DataFrame
    columns = [f'{m} mean' for m in methods] + [f'{m} std' for m in methods]
    df = pd.DataFrame(results, columns=['mean', 'std'])
    
    # Format into wide format
    final = pd.DataFrame({
        'proposing mean': df.loc[0, 'mean'],
        'proposing std': df.loc[0, 'std'],
        'baseline mean': df.loc[1, 'mean'],
        'baseline std': df.loc[1, 'std'],
        'sliding mean': df.loc[2, 'mean'],
        'sliding std': df.loc[2, 'std'],
        'oob_single mean': df.loc[3, 'mean'],
        'oob_single std': df.loc[3, 'std'],
        'areba mean': df.loc[4, 'mean'],
        'areba std': df.loc[4, 'std']
    }, index=[0])
    
    # Label the row with experiment details
    imtype = path.split('/')[-2]
    ir = path.split('/')[-1]
    final.index = [f"{imtype} {ir}"]
    
    return final
# give me an example
table_res_column(path, 'gmu')
# Out:
#           proposing mean  proposing std  baseline mean  baseline std  \
# noise 10        0.682546       0.032164       0.650312      0.023568
#
#           sliding mean  sliding std  oob_single mean  oob_single std  \
# noise 10      0.644622     0.024936         0.670951        0.021296
#
#           areba mean  areba std
# noise 10    0.626535   0.067932

# %% [markdown]
# ## Backup tables
# - Backup for the final results table (previous version)
# - from statsmodels.stats.anova import AnovaRM

# %%
import os 
import pandas as pd 
import itertools

def table_res_column(dic, metric):
    """ final result (gmu,rec)"""
    ## ---- set type ---- ##
    os.chdir(dic)
    
    ## ---- final results for each methods ---- ##
    base = pd.read_csv(f"baseline_{metric}.csv").iloc[:,-1]
    sliding = pd.read_csv(f"sliding_{metric}.csv").iloc[:,-1]
    oob_single = pd.read_csv(f"oob_single_{metric}.csv").iloc[:,-1]
    # oob = pd.read_csv(f"oob_{metric}.csv").iloc[:,-1]
    areba = pd.read_csv(f"areba_{metric}.csv").iloc[:,-1]
    mine = pd.read_csv(f"mine2_{metric}.csv").iloc[:,-1]
    
    ## ---- final dataframe ---- ##
    col = ['proposing mean', 'proposing std','baseline mean', 'baseline std','sliding mean', 'sliding std',
           'oob_single mean', 'oob_single std','oob mean', 'oob std','areba mean', 'areba std']
    
    val = [[mine.mean(), mine.std(),  base.mean(), base.std(), sliding.mean(), sliding.std(), 
            oob_single.mean(), oob_single.std() , oob.mean(), oob.std(), areba.mean(), areba.std()]]
    final = pd.DataFrame(val, columns=col)
    
    #----- lableing (index) ----- #
    boun = dic.split('\\')[-3]
    imtype = dic.split('\\')[-2]
    ir = dic.split('\\')[-1]
    final= final.rename(index = {0 : f"{imtype} {ir}"})
    
    return final

def table_res(boundary, metric):
    table = pd.DataFrame()
    for i in list(itertools.product(['safe', 'borderline', 'noise'],['10','1','0'])):
        dic = os.path.join(r"D:\USER DATA\Desktop\final res", boundary, i[0], i[1])
        if os.path.exists(dic):
            temp = table_res_column(dic, metric)
            table = pd.concat([table,temp])
    return table

# %%
table_res('sine', 'rec1')
# Out:
#                proposing mean  proposing std  baseline mean  baseline std  \
# safe 10              0.909270       0.021310       0.240487      0.144404
# safe 1               0.848183       0.078083       0.000000      0.000000
# safe 0               0.246947       0.276068       0.000000      0.000000
# borderline 10        0.831242       0.030971       0.024861      0.034915
# borderline 1         0.765076       0.101258       0.000000      0.000000
# borderline 0         0.167870       0.271201       0.000000      0.000000
# noise 10             0.658172       0.038633       0.072240      0.070846
#
#                sliding mean  sliding std  oob_single mean  oob_single std  \
# safe 10            0.685317     0.091843         0.807307        0.030917
# safe 1             0.103511     0.086126         0.356952        0.115899
# safe 0             0.000000     0.000000         0.021030        0.085654
# borderline 10      0.323429     0.104204         0.681395        0.039451
# ...

# %%
table_res('circle','gmu')
# Out:
#                proposing mean  proposing std  baseline mean  baseline std  \
# safe 10              0.901841       0.027719       0.150851      0.169161
# safe 1               0.869537       0.050877       0.000000      0.000000
# safe 0               0.443239       0.393176       0.000000      0.000000
# borderline 10        0.746091       0.043903       0.001366      0.013658
# borderline 1         0.724714       0.068289       0.000000      0.000000
# borderline 0         0.255966       0.326483       0.000000      0.000000
# noise 10             0.619825       0.045275       0.002341      0.012003
#
#                sliding mean  sliding std  oob_single mean  oob_single std  \
# safe 10            0.861541     0.059204         0.858823        0.022608
# safe 1             0.171884     0.153060         0.525716        0.088188
# safe 0             0.000000     0.000000         0.040747        0.144194
# borderline 10      0.655277     0.062161         0.675291        0.050807
# ...

# %%
table_res('circle','rec1')
# Out:
#                proposing mean  proposing std  baseline mean  baseline std  \
# safe 10              0.922483       0.024818       0.051347      0.076773
# safe 1               0.870070       0.063030       0.000000      0.000000
# safe 0               0.397299       0.391969       0.000000      0.000000
# borderline 10        0.785778       0.034961       0.000187      0.001871
# borderline 1         0.731780       0.086719       0.000000      0.000000
# borderline 0         0.207517       0.294588       0.000000      0.000000
# noise 10             0.693174       0.031406       0.000148      0.000961
#
#                sliding mean  sliding std  oob_single mean  oob_single std  \
# safe 10            0.748515     0.091398         0.833668        0.027257
# safe 1             0.052748     0.058996         0.318638        0.098490
# safe 0             0.000000     0.000000         0.026039        0.096724
# borderline 10      0.440198     0.072780         0.693915        0.040776
# ...

# %%
table_res('sea','gmu')
# Out:
#                proposing mean  proposing std  baseline mean  baseline std  \
# safe 10              0.984763       0.005380       0.984302      0.006347
# safe 1               0.978471       0.013878       0.402034      0.181373
# safe 0               0.702259       0.384489       0.000000      0.000000
# borderline 10        0.794380       0.028754       0.229475      0.062348
# borderline 1         0.775313       0.057014       0.000000      0.000000
# borderline 0         0.227874       0.306197       0.000000      0.000000
# noise 10             0.698360       0.028054       0.679984      0.022220
#
#                sliding mean  sliding std  oob_single mean  oob_single std  \
# safe 10            0.989609     0.004352         0.987575        0.005837
# safe 1             0.866378     0.045360         0.937381        0.029277
# safe 0             0.096364     0.217352         0.129450        0.258531
# borderline 10      0.575158     0.044426         0.803569        0.027242
# ...

# %%
table_res('sea','rec1')
# Out:
#                proposing mean  proposing std  baseline mean  baseline std  \
# safe 10              0.999669       0.001523       0.974436      0.011111
# safe 1               1.000000       0.000000       0.194210      0.117549
# safe 0               0.712488       0.410158       0.000000      0.000000
# borderline 10        0.955302       0.017883       0.056829      0.031090
# borderline 1         0.939097       0.084021       0.000000      0.000000
# borderline 0         0.205486       0.303772       0.000000      0.000000
# noise 10             0.601923       0.030649       0.472585      0.032158
#
#                sliding mean  sliding std  oob_single mean  oob_single std  \
# safe 10            0.982750     0.008398         0.991669        0.006414
# safe 1             0.753158     0.077812         0.887366        0.052736
# safe 0             0.056059     0.132077         0.083014        0.178182
# borderline 10      0.342344     0.052314         0.873433        0.021587
# ...
