# %% [markdown]
# # Synthetic data results
# - from statsmodels.stats.anova import AnovaRM

# %%
import pandas as pd
from typing import List
import itertools
import os
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# get the final value of a metric for a method
def final_value(path:str, method:str, metric:str) -> pd.Series:
    df = pd.read_csv(f"{path}/{method}_{metric}.csv")
    return df.iloc[:, -1]

def summary_table(path:str, methods:List[str], metrics:List[str]) -> pd.DataFrame:  
    results = []
    for method in methods:
        for metric in metrics:
            mean, std = final_value(path, method, metric).mean(), final_value(path, method, metric).std()
            results.append([method, metric, mean, std])
    return pd.DataFrame(results, columns=['method', 'metric', 'mean', 'std'])


def table_res_column(path: str, metric: str) -> pd.DataFrame:
    """Create a results table for a specific metric and path"""
    # Define methods
    methods = ['mine', 'baseline', 'sliding', 'oob_single', 'oob', 'areba']
    
    # Get final values for each method
    results = []
    for method in methods:
        mean, std = final_value(path, method, metric).mean(), final_value(path, method, metric).std()
        results.append([mean, std])
    
    # Create DataFrame
    columns = [f'{m} mean' for m in methods] + [f'{m} std' for m in methods]
    df = pd.DataFrame(results, columns=['mean', 'std'])
    
    # Format into wide format
    final = pd.DataFrame({
        'proposing mean': df.loc[0, 'mean'],
        'proposing std': df.loc[0, 'std'],
        'baseline mean': df.loc[1, 'mean'],
        'baseline std': df.loc[1, 'std'],
        'sliding mean': df.loc[2, 'mean'],
        'sliding std': df.loc[2, 'std'],
        'oob_single mean': df.loc[3, 'mean'],
        'oob_single std': df.loc[3, 'std'],
        'oob mean': df.loc[4, 'mean'],
        'oob std': df.loc[4, 'std'],
        'areba mean': df.loc[5, 'mean'],
        'areba std': df.loc[5, 'std']
    }, index=[0])
    
    # Label the row with experiment details
    imtype = path.split('/')[-2]
    ir = path.split('/')[-1]
    final.index = [f"{imtype} {ir}"]
    
    return final

def table_res_boundary(boundary: str, metric: str) -> pd.DataFrame:
    """Create a summary table for all scenarios under a boundary"""
    result_path = "<your path>/res"
    base_path = f"{result_path}/{boundary}"
    
    # Get all combinations of imtype and ir
    scenarios = list(itertools.product(['safe', 'borderline', 'noise'], ['10', '1', '0']))
    
    # Initialize empty DataFrame
    summary_table = pd.DataFrame()
    
    # Process each scenario
    for imtype, ir in scenarios:
        path = f"{base_path}/{imtype}/{ir}"
        if os.path.exists(path):
            # Get results for this scenario
            scenario_results = table_res_column(path, metric)
            # Concatenate with main table
            summary_table = pd.concat([summary_table, scenario_results])
    
    return summary_table

# %% [markdown]
# ## one table

# %%
result_path = "<your path>/res"
boundary = 'sea' # 'sine', 'sea', 'circle'
imtype = 'borderline' # 'safe', 'borderline', 'noise'
ir = '10' # '10', '1', '0'
# path
path = f"{result_path}/{boundary}/{imtype}/{ir}"
# methods and metrics
methods = ['baseline', 'sliding', 'oob_single', 'areba', 'mine'] #'oob', 
metrics = ['rec0', 'rec1', 'gmu']
summary_table(path, methods, metrics)
# Out:
#         method metric  mean   std
# 0     baseline   rec0 0.991 0.009
# 1     baseline   rec1 0.096 0.037
# 2     baseline    gmu 0.302 0.059
# 3      sliding   rec0 0.969 0.012
# 4      sliding   rec1 0.344 0.053
# 5      sliding    gmu 0.575 0.044
# 6   oob_single   rec0 0.787 0.053
# 7   oob_single   rec1 0.799 0.031
# 8   oob_single    gmu 0.792 0.028
# 9        areba   rec0 0.860 0.102
# 10       areba   rec1 0.619 0.333
# 11       areba    gmu 0.680 0.197
# 12        mine   rec0 0.667 0.050
# 13        mine   rec1 0.959 0.017
# 14        mine    gmu 0.799 0.030

# %% [markdown]
# ## Full results table
# - summary per boundary

# %%
table_res_boundary('sine', 'gmu')
# Out:
#                proposing mean  proposing std  baseline mean  baseline std  \
# safe 10                 0.886          0.025          0.568         0.146
# safe 1                  0.843          0.057          0.002         0.021
# safe 0                  0.343          0.351          0.000         0.000
# borderline 10           0.752          0.034          0.207         0.136
# borderline 1            0.712          0.079          0.000         0.000
# borderline 0            0.261          0.316          0.000         0.000
# noise 10                0.627          0.042          0.270         0.147
#
#                sliding mean  sliding std  oob_single mean  oob_single std  \
# safe 10               0.821        0.068            0.809           0.027
# safe 1                0.386        0.177            0.443           0.116
# safe 0                0.005        0.045            0.008           0.057
# borderline 10         0.592        0.086            0.671           0.037
# borderline 1          0.114        0.144            0.297           0.123
# borderline 0          0.000        0.000            0.004           0.045
# noise 10              0.515        0.057            0.601           0.025
#
#                oob mean  oob std  areba mean  areba std
# safe 10           0.823    0.021       0.802      0.101
# safe 1            0.540    0.104       0.580      0.136
# safe 0            0.027    0.113       0.188      0.285
# borderline 10     0.694    0.030       0.618      0.171
# borderline 1      0.395    0.135       0.329      0.188
# borderline 0      0.023    0.107       0.074      0.196
# noise 10          0.609    0.023       0.482      0.185

# %%
table_res_boundary('sea', 'gmu')
# Out:
#                proposing mean  proposing std  baseline mean  baseline std  \
# safe 10                 0.985          0.005          0.981         0.007
# safe 1                  0.974          0.023          0.558         0.115
# safe 0                  0.749          0.352          0.000         0.000
# borderline 10           0.799          0.030          0.302         0.059
# borderline 1            0.758          0.064          0.000         0.000
# borderline 0            0.194          0.290          0.000         0.000
# noise 10                0.682          0.032          0.650         0.024
#
#                sliding mean  sliding std  oob_single mean  oob_single std  \
# safe 10               0.989        0.006            0.982           0.007
# safe 1                0.857        0.053            0.884           0.042
# safe 0                0.162        0.273            0.103           0.225
# borderline 10         0.575        0.044            0.792           0.028
# borderline 1          0.088        0.116            0.436           0.124
# borderline 0          0.000        0.000            0.005           0.050
# noise 10              0.645        0.025            0.671           0.021
#
#                oob mean  oob std  areba mean  areba std
# safe 10           0.990    0.005       0.982      0.014
# safe 1            0.937    0.033       0.924      0.041
# safe 0            0.141    0.265       0.675      0.392
# borderline 10     0.813    0.026       0.680      0.197
# borderline 1      0.568    0.097       0.333      0.201
# borderline 0      0.038    0.134       0.056      0.172
# noise 10          0.673    0.020       0.627      0.068

# %%
table_res_boundary('circle', 'gmu')
# Out:
#                proposing mean  proposing std  baseline mean  baseline std  \
# safe 10                 0.907          0.019          0.536         0.130
# safe 1                  0.891          0.040          0.000         0.000
# safe 0                  0.487          0.409          0.000         0.000
# borderline 10           0.749          0.033          0.028         0.058
# borderline 1            0.734          0.058          0.000         0.000
# borderline 0            0.285          0.335          0.000         0.000
# noise 10                0.612          0.039          0.058         0.094
#
#                sliding mean  sliding std  oob_single mean  oob_single std  \
# safe 10               0.908        0.012            0.853           0.025
# safe 1                0.383        0.151            0.394           0.136
# safe 0                0.000        0.000            0.015           0.076
# borderline 10         0.703        0.027            0.673           0.049
# borderline 1          0.103        0.146            0.313           0.115
# borderline 0          0.000        0.000            0.009           0.067
# noise 10              0.548        0.037            0.572           0.058
#
#                oob mean  oob std  areba mean  areba std
# safe 10           0.876    0.018       0.867      0.084
# safe 1            0.471    0.120       0.627      0.112
# safe 0            0.028    0.116       0.234      0.319
# borderline 10     0.701    0.033       0.666      0.155
# borderline 1      0.405    0.109       0.386      0.155
# borderline 0      0.029    0.120       0.060      0.176
# noise 10          0.594    0.035       0.474      0.238

# %% [markdown]
# ## Statistical test
# - ANOVA
# - Tukey's HSD

# %%
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import numpy as np

def statistical_analysis(boundary: str, metric: str):
    """Perform ANOVA and Tukey's HSD test for a specific boundary and metric"""
    result_path = "<your path>/res"
    methods = ['mine', 'baseline', 'sliding', 'oob_single','oob', 'areba']
    
    # Get all combinations of imtype and ir
    scenarios = list(itertools.product(['safe', 'borderline', 'noise'], ['10', '1', '0']))
    
    print(f"\nStatistical Analysis for {boundary} boundary - {metric} metric")
    print("-" * 60)
    
    for imtype, ir in scenarios:
        path = f"{result_path}/{boundary}/{imtype}/{ir}"
        if os.path.exists(path):
            # Collect data
            data_values = []
            method_labels = []
            
            for method in methods:
                values = final_value(path, method, metric)
                data_values.extend(values)
                method_labels.extend([method] * len(values))
            
            # Perform one-way ANOVA
            method_groups = [final_value(path, method, metric) for method in methods]
            f_stat, p_value = stats.f_oneway(*method_groups)
            
            # Perform Tukey's HSD test
            tukey = pairwise_tukeyhsd(data_values, method_labels)
            
            # Get p-values
            from statsmodels.stats.multicomp import MultiComparison
            mc = MultiComparison(data_values, method_labels)
            precise_pvalues = mc.tukeyhsd().pvalues
            
            # Print results
            print(f"\nScenario: {imtype} {ir}")
            print(f"ANOVA results:")
            print(f"F-statistic = {f_stat:.3f}")
            print(f"p-value = {p_value:.3f}")
            
            print("\nTukey's HSD test results:")
            print("=" * 80)
            print(f"{'group1':>10} {'group2':>10} {'meandiff':>10} {'p-value':>10} {'lower':>10} {'upper':>10} {'reject':>6}")
            print("-" * 80)
            
            for idx, row in enumerate(tukey._results_table.data[1:]):
                print(f"{row[0]:>10} {row[1]:>10} {float(row[2]):>10.3f} {precise_pvalues[idx]:>10.3f} "
                      f"{float(row[3]):>10.3f} {float(row[4]):>10.3f} {row[5]:>6}")

# %%
statistical_analysis('sine', 'gmu')
# Out:
# Statistical Analysis for sine boundary - gmu metric
# ------------------------------------------------------------
#
# Scenario: safe 10
# ANOVA results:
# F-statistic = 193.669
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.234      0.000      0.000     -0.266 -0.2019
#      areba       mine      0.084      0.000      0.000      0.052 0.1162
#      areba        oob      0.022      0.386      0.386     -0.011 0.0537
#      areba oob_single      0.008      0.984      0.984     -0.024 0.0398
#      areba    sliding      0.019      0.532      0.532     -0.013 0.0512
#   baseline       mine      0.318      0.000      0.000      0.286 0.3502
#   baseline        oob      0.256      0.000      0.000      0.224 0.2877
#   baseline oob_single      0.242      0.000      0.000      0.209 0.2737
#   baseline    sliding      0.253      0.000      0.000      0.221 0.2851
#       mine        oob     -0.062      0.000      0.000     -0.095 -0.0304
#       mine oob_single     -0.076      0.000      0.000     -0.109 -0.0444
#       mine    sliding     -0.065      0.000      0.000     -0.097 -0.033
#        oob oob_single     -0.014      0.815      0.815     -0.046 0.0181
#        oob    sliding     -0.003      1.000      1.000     -0.035 0.0295
# oob_single    sliding      0.011      0.912      0.912     -0.021 0.0435
#
# Scenario: safe 1
# ANOVA results:
# F-statistic = 590.059
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.578      0.000      0.000     -0.624 -0.532
#      areba       mine      0.263      0.000      0.000      0.217 0.3094
#      areba        oob     -0.040      0.129      0.129     -0.086  0.006
#      areba oob_single     -0.137      0.000      0.000     -0.183 -0.0911
#      areba    sliding     -0.194      0.000      0.000     -0.240 -0.1483
#   baseline       mine      0.841      0.000      0.000      0.795 0.8874
#   baseline        oob      0.538      0.000      0.000      0.492  0.584
#   baseline oob_single      0.441      0.000      0.000      0.395 0.4869
#   baseline    sliding      0.384      0.000      0.000      0.338 0.4297
#       mine        oob     -0.303      0.000      0.000     -0.349 -0.2574
#       mine oob_single     -0.401      0.000      0.000     -0.447 -0.3544
#       mine    sliding     -0.458      0.000      0.000     -0.504 -0.4116
#        oob oob_single     -0.097      0.000      0.000     -0.143 -0.051
#        oob    sliding     -0.154      0.000      0.000     -0.200 -0.1082
# oob_single    sliding     -0.057      0.006      0.006     -0.103 -0.0111
#
# Scenario: safe 0
# ANOVA results:
# F-statistic = 53.577
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.188      0.000      0.000     -0.266 -0.1105
#      areba       mine      0.154      0.000      0.000      0.076 0.2322
#      areba        oob     -0.161      0.000      0.000     -0.239 -0.0833
#      areba oob_single     -0.180      0.000      0.000     -0.258 -0.1025
#      areba    sliding     -0.184      0.000      0.000     -0.262 -0.106
#   baseline       mine      0.343      0.000      0.000      0.265 0.4206
#   baseline        oob      0.027      0.919      0.919     -0.051 0.1051
#   baseline oob_single      0.008      1.000      1.000     -0.070 0.0859
#   baseline    sliding      0.004      1.000      1.000     -0.073 0.0824
#       mine        oob     -0.316      0.000      0.000     -0.394 -0.2377
#       mine oob_single     -0.335      0.000      0.000     -0.413 -0.2568
#       mine    sliding     -0.338      0.000      0.000     -0.416 -0.2603
#        oob oob_single     -0.019      0.982      0.982     -0.097 0.0588
#        oob    sliding     -0.023      0.962      0.962     -0.101 0.0553
# oob_single    sliding     -0.004      1.000      1.000     -0.081 0.0744
#
# Scenario: borderline 10
# ANOVA results:
# F-statistic = 391.037
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.411      0.000      0.000     -0.451 -0.3709
#      areba       mine      0.134      0.000      0.000      0.094 0.1744
#      areba        oob      0.076      0.000      0.000      0.036 0.1162
#      areba oob_single      0.053      0.002      0.002      0.013 0.0932
#      areba    sliding     -0.026      0.432      0.432     -0.066 0.0141
#   baseline       mine      0.545      0.000      0.000      0.505 0.5853
#   baseline        oob      0.487      0.000      0.000      0.447 0.5271
#   baseline oob_single      0.464      0.000      0.000      0.424 0.5041
#   baseline    sliding      0.385      0.000      0.000      0.345 0.4249
#       mine        oob     -0.058      0.001      0.001     -0.098 -0.0182
#       mine oob_single     -0.081      0.000      0.000     -0.121 -0.0412
#       mine    sliding     -0.160      0.000      0.000     -0.200 -0.1204
#        oob oob_single     -0.023      0.570      0.570     -0.063  0.017
#        oob    sliding     -0.102      0.000      0.000     -0.142 -0.0622
# oob_single    sliding     -0.079      0.000      0.000     -0.119 -0.0392
#
# Scenario: borderline 1
# ANOVA results:
# F-statistic = 380.354
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.329      0.000      0.000     -0.380 -0.2781
#      areba       mine      0.383      0.000      0.000      0.332 0.4341
#      areba        oob      0.066      0.003      0.003      0.015  0.117
#      areba oob_single     -0.032      0.480      0.480     -0.083 0.0193
#      areba    sliding     -0.215      0.000      0.000     -0.266 -0.1641
#   baseline       mine      0.712      0.000      0.000      0.661 0.7634
#   baseline        oob      0.395      0.000      0.000      0.344 0.4462
#   baseline oob_single      0.297      0.000      0.000      0.246 0.3486
#   baseline    sliding      0.114      0.000      0.000      0.063 0.1652
#       mine        oob     -0.317      0.000      0.000     -0.368 -0.266
#       mine oob_single     -0.415      0.000      0.000     -0.466 -0.3637
#       mine    sliding     -0.598      0.000      0.000     -0.649 -0.5471
#        oob oob_single     -0.098      0.000      0.000     -0.149 -0.0465
#        oob    sliding     -0.281      0.000      0.000     -0.332 -0.2299
# oob_single    sliding     -0.183      0.000      0.000     -0.234 -0.1323
#
# Scenario: borderline 0
# ANOVA results:
# F-statistic = 41.206
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.074      0.014      0.014     -0.138 -0.0096
#      areba       mine      0.187      0.000      0.000      0.123 0.2513
#      areba        oob     -0.051      0.219      0.219     -0.115 0.0138
#      areba oob_single     -0.070      0.026      0.026     -0.134 -0.0051
#      areba    sliding     -0.074      0.014      0.014     -0.138 -0.0096
#   baseline       mine      0.261      0.000      0.000      0.197 0.3253
#   baseline        oob      0.023      0.904      0.904     -0.041 0.0877
#   baseline oob_single      0.004      1.000      1.000     -0.060 0.0688
#   baseline    sliding      0.000      1.000      1.000     -0.064 0.0644
#       mine        oob     -0.237      0.000      0.000     -0.302 -0.1732
#       mine oob_single     -0.257      0.000      0.000     -0.321 -0.1921
#       mine    sliding     -0.261      0.000      0.000     -0.325 -0.1966
#        oob oob_single     -0.019      0.960      0.960     -0.083 0.0454
#        oob    sliding     -0.023      0.904      0.904     -0.088  0.041
# oob_single    sliding     -0.004      1.000      1.000     -0.069 0.0599
#
# Scenario: noise 10
# ANOVA results:
# F-statistic = 174.266
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.212      0.000      0.000     -0.253 -0.171
#      areba       mine      0.145      0.000      0.000      0.104 0.1865
#      areba        oob      0.127      0.000      0.000      0.086 0.1684
#      areba oob_single      0.119      0.000      0.000      0.078 0.1607
#      areba    sliding      0.033      0.188      0.188     -0.008 0.0745
#   baseline       mine      0.357      0.000      0.000      0.316 0.3986
#   baseline        oob      0.340      0.000      0.000      0.298 0.3806
#   baseline oob_single      0.332      0.000      0.000      0.290 0.3728
#   baseline    sliding      0.245      0.000      0.000      0.204 0.2866
#       mine        oob     -0.018      0.810      0.810     -0.059 0.0231
#       mine oob_single     -0.026      0.470      0.470     -0.067 0.0153
#       mine    sliding     -0.112      0.000      0.000     -0.153 -0.0709
#        oob oob_single     -0.008      0.994      0.995     -0.049 0.0333
#        oob    sliding     -0.094      0.000      0.000     -0.135 -0.0528
# oob_single    sliding     -0.086      0.000      0.000     -0.127 -0.0451

# %%
statistical_analysis('sea', 'gmu')
# Out:
# Statistical Analysis for sea boundary - gmu metric
# ------------------------------------------------------------
#
# Scenario: safe 10
# ANOVA results:
# F-statistic = 22.916
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.001      0.834      0.834     -0.004 0.0018
#      areba       mine      0.002      0.246      0.246     -0.001 0.0056
#      areba        oob      0.007      0.000      0.000      0.004 0.0103
#      areba oob_single     -0.001      0.997      0.997     -0.004 0.0026
#      areba    sliding      0.007      0.000      0.000      0.004   0.01
#   baseline       mine      0.004      0.010      0.010      0.001  0.007
#   baseline        oob      0.009      0.000      0.000      0.005 0.0117
#   baseline oob_single      0.001      0.979      0.979     -0.002  0.004
#   baseline    sliding      0.008      0.000      0.000      0.005 0.0114
#       mine        oob      0.005      0.000      0.000      0.002 0.0079
#       mine oob_single     -0.003      0.084      0.084     -0.006 0.0002
#       mine    sliding      0.004      0.001      0.001      0.001 0.0076
#        oob oob_single     -0.008      0.000      0.000     -0.011 -0.0045
#        oob    sliding     -0.000      1.000      1.000     -0.004 0.0029
# oob_single    sliding      0.007      0.000      0.000      0.004 0.0106
#
# Scenario: safe 1
# ANOVA results:
# F-statistic = 654.498
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.367      0.000      0.000     -0.391 -0.3428
#      areba       mine      0.050      0.000      0.000      0.026 0.0739
#      areba        oob      0.013      0.641      0.641     -0.011 0.0369
#      areba oob_single     -0.040      0.000      0.000     -0.064 -0.0161
#      areba    sliding     -0.068      0.000      0.000     -0.092 -0.0437
#   baseline       mine      0.417      0.000      0.000      0.393 0.4407
#   baseline        oob      0.380      0.000      0.000      0.356 0.4036
#   baseline oob_single      0.327      0.000      0.000      0.303 0.3507
#   baseline    sliding      0.299      0.000      0.000      0.275 0.3231
#       mine        oob     -0.037      0.000      0.000     -0.061 -0.0131
#       mine oob_single     -0.090      0.000      0.000     -0.114 -0.066
#       mine    sliding     -0.118      0.000      0.000     -0.142 -0.0936
#        oob oob_single     -0.053      0.000      0.000     -0.077 -0.0289
#        oob    sliding     -0.081      0.000      0.000     -0.104 -0.0565
# oob_single    sliding     -0.028      0.013      0.013     -0.052 -0.0036
#
# Scenario: safe 0
# ANOVA results:
# F-statistic = 130.665
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.675      0.000      0.000     -0.789 -0.5617
#      areba       mine      0.073      0.436      0.436     -0.040 0.1869
#      areba        oob     -0.535      0.000      0.000     -0.648 -0.4211
#      areba oob_single     -0.572      0.000      0.000     -0.686 -0.4586
#      areba    sliding     -0.513      0.000      0.000     -0.627 -0.3997
#   baseline       mine      0.749      0.000      0.000      0.635 0.8622
#   baseline        oob      0.141      0.006      0.006      0.027 0.2541
#   baseline oob_single      0.103      0.100      0.100     -0.010 0.2166
#   baseline    sliding      0.162      0.001      0.001      0.048 0.2755
#       mine        oob     -0.608      0.000      0.000     -0.722 -0.4945
#       mine oob_single     -0.645      0.000      0.000     -0.759 -0.532
#       mine    sliding     -0.587      0.000      0.000     -0.700 -0.4731
#        oob oob_single     -0.037      0.935      0.935     -0.151 0.0761
#        oob    sliding      0.021      0.995      0.995     -0.092 0.1349
# oob_single    sliding      0.059      0.676      0.676     -0.055 0.1724
#
# Scenario: borderline 10
# ANOVA results:
# F-statistic = 503.053
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.378      0.000      0.000     -0.414 -0.3423
#      areba       mine      0.119      0.000      0.000      0.083 0.1545
#      areba        oob      0.133      0.000      0.000      0.097 0.1688
#      areba oob_single      0.112      0.000      0.000      0.076 0.1479
#      areba    sliding     -0.105      0.000      0.000     -0.141 -0.0693
#   baseline       mine      0.497      0.000      0.000      0.461 0.5325
#   baseline        oob      0.511      0.000      0.000      0.475 0.5468
#   baseline oob_single      0.490      0.000      0.000      0.455 0.5259
#   baseline    sliding      0.273      0.000      0.000      0.237 0.3087
#       mine        oob      0.014      0.863      0.863     -0.021   0.05
#       mine oob_single     -0.007      0.995      0.995     -0.042  0.029
#       mine    sliding     -0.224      0.000      0.000     -0.260 -0.1882
#        oob oob_single     -0.021      0.548      0.547     -0.057 0.0148
#        oob    sliding     -0.238      0.000      0.000     -0.274 -0.2024
# oob_single    sliding     -0.217      0.000      0.000     -0.253 -0.1815
#
# Scenario: borderline 1
# ANOVA results:
# F-statistic = 596.489
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.333      0.000      0.000     -0.381 -0.2857
#      areba       mine      0.424      0.000      0.000      0.377  0.472
#      areba        oob      0.235      0.000      0.000      0.187 0.2821
#      areba oob_single      0.103      0.000      0.000      0.055 0.1502
#      areba    sliding     -0.245      0.000      0.000     -0.292 -0.1973
#   baseline       mine      0.758      0.000      0.000      0.710 0.8051
#   baseline        oob      0.568      0.000      0.000      0.520 0.6152
#   baseline oob_single      0.436      0.000      0.000      0.388 0.4833
#   baseline    sliding      0.088      0.000      0.000      0.041 0.1359
#       mine        oob     -0.190      0.000      0.000     -0.237 -0.1424
#       mine oob_single     -0.322      0.000      0.000     -0.369 -0.2743
#       mine    sliding     -0.669      0.000      0.000     -0.717 -0.6218
#        oob oob_single     -0.132      0.000      0.000     -0.179 -0.0844
#        oob    sliding     -0.479      0.000      0.000     -0.527 -0.4319
# oob_single    sliding     -0.347      0.000      0.000     -0.395   -0.3
#
# Scenario: borderline 0
# ANOVA results:
# F-statistic = 24.853
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.056      0.091      0.091     -0.116 0.0048
#      areba       mine      0.138      0.000      0.000      0.077 0.1984
#      areba        oob     -0.018      0.963      0.963     -0.078  0.043
#      areba oob_single     -0.051      0.159      0.160     -0.111 0.0098
#      areba    sliding     -0.056      0.091      0.091     -0.116 0.0048
#   baseline       mine      0.194      0.000      0.000      0.133  0.254
#   baseline        oob      0.038      0.463      0.464     -0.022 0.0986
#   baseline oob_single      0.005      1.000      1.000     -0.056 0.0655
#   baseline    sliding      0.000      1.000      1.000     -0.060 0.0605
#       mine        oob     -0.155      0.000      0.000     -0.216 -0.0949
#       mine oob_single     -0.189      0.000      0.000     -0.249 -0.1281
#       mine    sliding     -0.194      0.000      0.000     -0.254 -0.1331
#        oob oob_single     -0.033      0.619      0.620     -0.094 0.0273
#        oob    sliding     -0.038      0.463      0.464     -0.099 0.0223
# oob_single    sliding     -0.005      1.000      1.000     -0.066 0.0555
#
# Scenario: noise 10
# ANOVA results:
# F-statistic = 34.444
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline      0.024      0.000      0.000      0.009 0.0381
#      areba       mine      0.056      0.000      0.000      0.041 0.0702
#      areba        oob      0.046      0.000      0.000      0.032  0.061
#      areba oob_single      0.044      0.000      0.000      0.030 0.0586
#      areba    sliding      0.018      0.006      0.006      0.003 0.0323
#   baseline       mine      0.032      0.000      0.000      0.018 0.0466
#   baseline        oob      0.023      0.000      0.000      0.008 0.0374
#   baseline oob_single      0.021      0.001      0.001      0.006  0.035
#   baseline    sliding     -0.006      0.863      0.864     -0.020 0.0087
#       mine        oob     -0.009      0.455      0.455     -0.024 0.0053
#       mine oob_single     -0.012      0.202      0.202     -0.026 0.0029
#       mine    sliding     -0.038      0.000      0.000     -0.052 -0.0234
#        oob oob_single     -0.002      0.997      0.997     -0.017 0.0121
#        oob    sliding     -0.029      0.000      0.000     -0.043 -0.0142
# oob_single    sliding     -0.026      0.000      0.000     -0.041 -0.0118

# %%
statistical_analysis('circle', 'gmu')
# Out:
# Statistical Analysis for circle boundary - gmu metric
# ------------------------------------------------------------
#
# Scenario: safe 10
# ANOVA results:
# F-statistic = 484.800
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.331      0.000      0.000     -0.358 -0.3051
#      areba       mine      0.040      0.000      0.000      0.013 0.0661
#      areba        oob      0.009      0.932      0.932     -0.018  0.035
#      areba oob_single     -0.014      0.622      0.622     -0.041 0.0119
#      areba    sliding      0.040      0.000      0.000      0.014 0.0666
#   baseline       mine      0.371      0.000      0.000      0.345 0.3975
#   baseline        oob      0.340      0.000      0.000      0.314 0.3665
#   baseline oob_single      0.317      0.000      0.000      0.291 0.3433
#   baseline    sliding      0.372      0.000      0.000      0.345  0.398
#       mine        oob     -0.031      0.010      0.010     -0.057 -0.0047
#       mine oob_single     -0.054      0.000      0.000     -0.080 -0.0279
#       mine    sliding      0.001      1.000      1.000     -0.026 0.0268
#        oob oob_single     -0.023      0.120      0.120     -0.049 0.0031
#        oob    sliding      0.032      0.008      0.008      0.005 0.0579
# oob_single    sliding      0.055      0.000      0.000      0.029  0.081
#
# Scenario: safe 1
# ANOVA results:
# F-statistic = 750.021
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.627      0.000      0.000     -0.670 -0.583
#      areba       mine      0.264      0.000      0.000      0.221 0.3078
#      areba        oob     -0.156      0.000      0.000     -0.199 -0.1122
#      areba oob_single     -0.233      0.000      0.000     -0.276 -0.1892
#      areba    sliding     -0.244      0.000      0.000     -0.288 -0.2005
#   baseline       mine      0.891      0.000      0.000      0.847 0.9344
#   baseline        oob      0.471      0.000      0.000      0.427 0.5144
#   baseline oob_single      0.394      0.000      0.000      0.350 0.4373
#   baseline    sliding      0.383      0.000      0.000      0.339 0.4261
#       mine        oob     -0.420      0.000      0.000     -0.464 -0.3764
#       mine oob_single     -0.497      0.000      0.000     -0.541 -0.4535
#       mine    sliding     -0.508      0.000      0.000     -0.552 -0.4647
#        oob oob_single     -0.077      0.000      0.000     -0.121 -0.0335
#        oob    sliding     -0.088      0.000      0.000     -0.132 -0.0447
# oob_single    sliding     -0.011      0.977      0.977     -0.055 0.0324
#
# Scenario: safe 0
# ANOVA results:
# F-statistic = 81.705
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.234      0.000      0.000     -0.322 -0.1453
#      areba       mine      0.254      0.000      0.000      0.165 0.3422
#      areba        oob     -0.206      0.000      0.000     -0.294 -0.1174
#      areba oob_single     -0.218      0.000      0.000     -0.307  -0.13
#      areba    sliding     -0.234      0.000      0.000     -0.322 -0.1453
#   baseline       mine      0.487      0.000      0.000      0.399  0.576
#   baseline        oob      0.028      0.947      0.947     -0.061 0.1164
#   baseline oob_single      0.015      0.996      0.996     -0.073 0.1038
#   baseline    sliding      0.000      1.000      1.000     -0.088 0.0885
#       mine        oob     -0.460      0.000      0.000     -0.548 -0.3711
#       mine oob_single     -0.472      0.000      0.000     -0.561 -0.3836
#       mine    sliding     -0.487      0.000      0.000     -0.576 -0.3989
#        oob oob_single     -0.013      0.999      0.999     -0.101  0.076
#        oob    sliding     -0.028      0.947      0.947     -0.116 0.0607
# oob_single    sliding     -0.015      0.996      0.996     -0.104 0.0733
#
# Scenario: borderline 10
# ANOVA results:
# F-statistic = 1388.184
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.638      0.000      0.000     -0.668 -0.6082
#      areba       mine      0.083      0.000      0.000      0.053 0.1131
#      areba        oob      0.035      0.011      0.011      0.005 0.0651
#      areba oob_single      0.007      0.981      0.981     -0.022 0.0373
#      areba    sliding      0.037      0.005      0.005      0.007 0.0673
#   baseline       mine      0.721      0.000      0.000      0.692 0.7512
#   baseline        oob      0.673      0.000      0.000      0.643 0.7031
#   baseline oob_single      0.645      0.000      0.000      0.616 0.6754
#   baseline    sliding      0.675      0.000      0.000      0.646 0.7054
#       mine        oob     -0.048      0.000      0.000     -0.078 -0.0182
#       mine oob_single     -0.076      0.000      0.000     -0.106 -0.0459
#       mine    sliding     -0.046      0.000      0.000     -0.076 -0.016
#        oob oob_single     -0.028      0.087      0.087     -0.058 0.0022
#        oob    sliding      0.002      1.000      1.000     -0.028 0.0321
# oob_single    sliding      0.030      0.049      0.049      0.000 0.0599
#
# Scenario: borderline 1
# ANOVA results:
# F-statistic = 538.914
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.386      0.000      0.000     -0.431 -0.3411
#      areba       mine      0.348      0.000      0.000      0.303  0.393
#      areba        oob      0.019      0.841      0.841     -0.026 0.0636
#      areba oob_single     -0.073      0.000      0.000     -0.118 -0.0281
#      areba    sliding     -0.283      0.000      0.000     -0.328 -0.2381
#   baseline       mine      0.734      0.000      0.000      0.689 0.7789
#   baseline        oob      0.405      0.000      0.000      0.360 0.4496
#   baseline oob_single      0.313      0.000      0.000      0.268 0.3579
#   baseline    sliding      0.103      0.000      0.000      0.058 0.1479
#       mine        oob     -0.329      0.000      0.000     -0.374 -0.2844
#       mine oob_single     -0.421      0.000      0.000     -0.466 -0.3762
#       mine    sliding     -0.631      0.000      0.000     -0.676 -0.5861
#        oob oob_single     -0.092      0.000      0.000     -0.137 -0.0468
#        oob    sliding     -0.302      0.000      0.000     -0.347 -0.2568
# oob_single    sliding     -0.210      0.000      0.000     -0.255 -0.1651
#
# Scenario: borderline 0
# ANOVA results:
# F-statistic = 45.206
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.060      0.104      0.104     -0.127 0.0065
#      areba       mine      0.225      0.000      0.000      0.158 0.2913
#      areba        oob     -0.031      0.770      0.770     -0.097 0.0356
#      areba oob_single     -0.051      0.253      0.253     -0.117  0.016
#      areba    sliding     -0.060      0.104      0.104     -0.127 0.0065
#   baseline       mine      0.285      0.000      0.000      0.218 0.3512
#   baseline        oob      0.029      0.811      0.811     -0.037 0.0956
#   baseline oob_single      0.009      0.999      0.999     -0.057  0.076
#   baseline    sliding      0.000      1.000      1.000     -0.067 0.0665
#       mine        oob     -0.256      0.000      0.000     -0.322 -0.1891
#       mine oob_single     -0.275      0.000      0.000     -0.342 -0.2088
#       mine    sliding     -0.285      0.000      0.000     -0.351 -0.2183
#        oob oob_single     -0.020      0.959      0.959     -0.086 0.0468
#        oob    sliding     -0.029      0.811      0.811     -0.096 0.0374
# oob_single    sliding     -0.009      0.999      0.999     -0.076  0.057
#
# Scenario: noise 10
# ANOVA results:
# F-statistic = 364.131
# p-value = 0.000
#
# Tukey's HSD test results:
# ================================================================================
#     group1     group2   meandiff    p-value      lower      upper reject
# --------------------------------------------------------------------------------
#      areba   baseline     -0.416      0.000      0.000     -0.460 -0.3712
#      areba       mine      0.138      0.000      0.000      0.093 0.1826
#      areba        oob      0.120      0.000      0.000      0.076 0.1649
#      areba oob_single      0.098      0.000      0.000      0.053 0.1425
#      areba    sliding      0.074      0.000      0.000      0.029 0.1182
#   baseline       mine      0.554      0.000      0.000      0.509 0.5983
#   baseline        oob      0.536      0.000      0.000      0.491 0.5806
#   baseline oob_single      0.514      0.000      0.000      0.469 0.5583
#   baseline    sliding      0.489      0.000      0.000      0.445  0.534
#       mine        oob     -0.018      0.866      0.867     -0.062 0.0269
#       mine oob_single     -0.040      0.107      0.107     -0.085 0.0045
#       mine    sliding     -0.064      0.001      0.001     -0.109 -0.0198
#        oob oob_single     -0.022      0.707      0.707     -0.067 0.0222
#        oob    sliding     -0.047      0.034      0.034     -0.091 -0.002
# oob_single    sliding     -0.024      0.627      0.627     -0.069 0.0203
